# %%
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns

# %% [markdown]
# # Distribución Hipergeométrica

# %% [markdown]
# ## Introducción
# La distribución hipergeométrica es una distribución discreta que modela el número de eventos en una muestra de tamaño fijo cuando usted conoce el número total de elementos en la población de la cual proviene la muestra. Cada elemento de la muestra tiene dos resultados posibles (es un evento o un no evento).
#
# Las muestras no tienen reemplazo, por lo que cada elemento de la muestra es diferente.
# Cuando se elige un elemento de la población, no se puede volver a elegir. Por lo tanto, la probabilidad de que un elemento sea seleccionado aumenta con cada ensayo, presuponiendo que aún no haya sido seleccionado.

# %% [markdown]
# ## Descripción

# %% [markdown]
# ![Formula Hipergeometrica](https://image.slidesharecdn.com/distribucionhipergeometrica-131110193251-phpapp01/95/distribucion-hipergeometrica-3-638.jpg?cb=1384112015)

# %%
M, n, N = 30, 10, 12 
hipergeometrica = stats.hypergeom(M, n, N) 
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='#5856d6', lw=5, alpha=0.5)
plt.title('Distribución Hipergeométrica')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
aleatorios = hipergeometrica.rvs(1000)  # Dist hipergeometrica
plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Hipergeométrica')
plt.show()

# %% [markdown]
# # Uniforme

# %% [markdown]
# ## Introducción
# La distribución uniforme es  es una familia de distribuciones de probabilidad para variables aleatorias, tales que para cada miembro de la familia, todos los intervalos de igual longitud en la distribución en su rango son igualmente probables.

# %% [markdown]
# ## Descripción

# %% [markdown]
# ![Distribución uniforme](https://i.ytimg.com/vi/686xBXYiDq8/maxresdefault.jpg)

# %%
uniforme = stats.uniform()
x = np.linspace(uniforme.ppf(0.01),
                uniforme.ppf(0.99), 100)
fp = uniforme.pdf(x)
fig, ax = plt.subplots()
ax.plot(x, fp, '--')
ax.vlines(x, 0, fp, colors='#5856d6', lw=5, alpha=0.8)
ax.set_yticks([0., 0.2, 0.4, 0.6, 0.8, 1., 1.2])
plt.title('Distribución Uniforme')
plt.show()

# %%
aleatorios = uniforme.rvs(100000)
plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Uniforme')
plt.show()

# %% [markdown]
# # Distribución Binomial Negativa

# %% [markdown]
# ## Introducción
# Es una generalización de la distribución geométrica. La
# variable aleatoria X cuenta el número de ensayos hasta la
# ocurrencia de r éxitos. Los parámetros de la distribución
# son r y p
#
# La distribución binomial negativa también puede modelar el número de no eventos que deben ocurrir para que se observe el número especificado de resultados.

# %% [markdown]
# ## Descripción
#
# ![Distribución binomial negativa](https://i.ytimg.com/vi/Snoa15Njvh8/maxresdefault.jpg)

# %%
from scipy.stats import nbinom  
numargs = nbinom.numargs
a, b = 0.2, 0.8
rv = nbinom(a, b)
distribution = np.linspace(0, np.minimum(rv.dist.b, 1))
print("DBN : \n", distribution)
plot = plt.plot(distribution, rv.ppf(distribution))
# Out:
# DBN :
#  [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
#  0.48979592 0.51020408 0.53061224 0.55102041 0.57142857 0.59183673
#  0.6122449  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571
#  0.73469388 0.75510204 0.7755102  0.79591837 0.81632653 0.83673469
#  0.85714286 0.87755102 0.89795918 0.91836735 0.93877551 0.95918367
#  0.97959184 1.        ]

# %%
plt.hist(distribution, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Binomial Negativa')
plt.show()
